# %% [markdown]
# # Social Doors Group Level Analyses

# %%
import os
import glob
import pandas as pd

from nltools.stats import zscore, regress, find_spikes
from nltools.data import Brain_Data, Design_Matrix
from nilearn.plotting import view_img, glass_brain, plot_stat_map

import matplotlib.pyplot as plt

# %% [markdown]
# ### Set paths and set subjects

# %%
bids_dir = '/data/projects/social_doors/'


os.chdir(bids_dir)

data_dir = os.path.join(bids_dir, 'derivatives','social_doors')

# Define subject list
#subjs_scan_info = pd.read_csv(bids_dir+'/derivatives/mriqc/mriqc_summary_poor.csv')
#subjs_list = list(subjs_scan_info['subject'].unique())
#subjs_list.sort()
subjs_list = pd.read_csv(bids_dir+'derivatives/participants_good.tsv', sep='\t')
subjs_list_kids = subjs_list[subjs_list['group']=='kid']['participant_id'].to_list()
subjs_list_colg = subjs_list[subjs_list['group']=='college']['participant_id'].to_list()

print('Found '+str(len(subjs_list_kids))+' adolescent subjects')
print('Found '+str(len(subjs_list_colg))+' college subjects')
# Out:
# Found 32 adolescent subjects
# Found 31 college subjects

# %% [markdown]
# # Group Analysis
# Perform a one sample t-test and multiple comparisons correction

# %%
# Define mask
#subj_mni_mask = bids_dir+"derivatives/reliability_analysis/relscenarios/Anatomy/sub-301_space-MNI152NLin2009cAsym_label-GM_probseg_bin.nii.gz"
subj_mni_mask = bids_dir+'derivatives/social_doors/sub-010/suit/iw_c_sub-010_run-1_space-MNI152NLin2009cAsym_desc-preproc_T1w_pcereb_u_a_sub-010_run-1_space-MNI152NLin2009cAsym_label-GM_probseg.nii'

# Define contrasts
contrasts = ['facesVoutcm', 'all_winVlos', 'positive_winVlos']
tasks = ['mdoors', 'social']
groups = ['kids', 'colg']

# Define dictionary to store stats
univ_stats_all = {}

for group in groups:
    if group == 'kids':
        temp_subj_list = subjs_list_kids
    elif group == 'colg':
        temp_subj_list = subjs_list_colg
        
    for task in tasks:
        for contrast in contrasts:
            print('Calculating '+group+' '+task+' '+contrast+' contrast')
            
            # Find subject tmaps for a given contrast
            temp_file_list = []
            for subj in temp_subj_list:
                temp_file = glob.glob(os.path.join(data_dir, subj, 'suit', 
                                                   'iw_wdtmap_'+task+'_'+contrast+'_u_a_'+subj+'_run-1_space-MNI152NLin2009cAsym_label-GM_probseg.nii'))
                temp_file_list = temp_file_list + temp_file

            temp_file_list.sort()
            

            # Load data
            temp_univ = Brain_Data(temp_file_list, mask=subj_mni_mask)

            # Perform FDR multiple comparisons correction
            univ_stats_all[group+'_'+task+'_'+contrast] = temp_univ.ttest(threshold_dict={'fdr':.05})

            # Export as nifti
            univ_stats_all[group+'_'+task+'_'+contrast]['t'].write(os.path.join(data_dir,'group','tmap_'+group+'_'+task+'_'+contrast+'_suit_unc.nii.gz'))
            univ_stats_all[group+'_'+task+'_'+contrast]['thr_t'].write(os.path.join(data_dir,'group','tmap_'+group+'_'+task+'_'+contrast+'_suit_fdr05.nii.gz'))
# Out:
# Calculating kids mdoors facesVoutcm contrast
# Calculating kids mdoors all_winVlos contrast
# Calculating kids mdoors positive_winVlos contrast
# Calculating kids social facesVoutcm contrast
# Calculating kids social all_winVlos contrast
# Calculating kids social positive_winVlos contrast
# Calculating colg mdoors facesVoutcm contrast
# Calculating colg mdoors all_winVlos contrast
# Calculating colg mdoors positive_winVlos contrast
# Calculating colg social facesVoutcm contrast
# Calculating colg social all_winVlos contrast
# Calculating colg social positive_winVlos contrast

# %% [markdown]
# # Decision vs Outcome

# %% [markdown]
# ## Monetary

# %%
plot_stat_map(univ_stats_all['kids_mdoors_facesVoutcm']['t'].to_nifti(), threshold=3,
    cut_coords=range(-65, 66, 10), display_mode='x', vmax=10, colorbar=True,
    title='Uncorrected')
#plt.savefig(data_dir+'/group/tmap_facesVoutcm_unc.png')

plot_stat_map(univ_stats_all['kids_mdoors_facesVoutcm']['thr_t'].to_nifti(), threshold=3,
    cut_coords=range(-65, 66, 10), display_mode='x', vmax=10, colorbar=True,
    title='FDR .05')
#plt.savefig(data_dir+'/group/tmap_faces_outcm_fdr05.png')

# %%
plot_stat_map(univ_stats_all['colg_mdoors_facesVoutcm']['t'].to_nifti(), threshold=3,
    cut_coords=range(-65, 66, 10), display_mode='x', vmax=10, colorbar=True,
    title='Uncorrected')
#plt.savefig(data_dir+'/group/tmap_facesVoutcm_unc.png')

plot_stat_map(univ_stats_all['colg_mdoors_facesVoutcm']['thr_t'].to_nifti(), threshold=3,
    cut_coords=range(-65, 66, 10), display_mode='x', vmax=10, colorbar=True,
    title='FDR .05')
#plt.savefig(data_dir+'/group/tmap_faces_outcm_fdr05.png')

# %% [markdown]
# ## Social

# %%
plot_stat_map(univ_stats_all['kids_social_facesVoutcm']['t'].to_nifti(), threshold=3,
    cut_coords=range(-65, 66, 10), display_mode='x', vmax=10, colorbar=True,
    title='Uncorrected')
plt.savefig(data_dir+'/group/tmap_kids_social_facesVoutcm_unc.png')

plot_stat_map(univ_stats_all['kids_social_facesVoutcm']['thr_t'].to_nifti(), threshold=3,
    cut_coords=range(-65, 66, 10), display_mode='x', vmax=10, colorbar=True,
    title='FDR .05')
plt.savefig(data_dir+'/group/tmap_kids_social_faces_outcm_fdr05.png')

# %%
plot_stat_map(univ_stats_all['colg_social_facesVoutcm']['t'].to_nifti(), threshold=3,
    cut_coords=range(-65, 66, 10), display_mode='x', vmax=10, colorbar=True,
    title='Uncorrected')
plt.savefig(data_dir+'/group/tmap_colg_social_facesVoutcm_unc.png')

plot_stat_map(univ_stats_all['colg_social_facesVoutcm']['thr_t'].to_nifti(), threshold=3,
    cut_coords=range(-65, 66, 10), display_mode='x', vmax=10, colorbar=True,
    title='FDR .05')
plt.savefig(data_dir+'/group/tmap_colg_social_facesVoutcm_fdr05.png')

# %%
# Import the Suit package
import SUITPy.flatmap as flatmap
import matplotlib.pyplot as plt
import nibabel as nb
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
funcdata = flatmap.vol_to_surf(data_dir+'/group/tmap_kids_social_facesVoutcm_suit_fdr05.nii.gz')
print('Output is a np.array of size:',funcdata.shape)
# Out:
# Output is a np.array of size: (28935, 1)

# %%
cb_flatmap = flatmap.plot(data=funcdata, cmap='coolwarm', \
                        threshold=[0,3], \
                        new_figure=True, \
                        colorbar=True, \
                        render='matplotlib')

cb_flatmap.figure.savefig(data_dir+'/group/tmap_kids_social_facesVoutcm_suit_fdr05_flatmap.png')

cb_flatmap
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/colorbar.py:1241: RuntimeWarning: invalid value encountered in true_divide
#   self._boundaries[self._inside][0])
# /opt/anaconda3/lib/python3.7/site-packages/SUITPy/flatmap.py:1005: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   format=cbar_tick_format, orientation='vertical')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1947712/3103020031.py in <module>
#       3                         new_figure=True, \
#       4                         colorbar=True, \
# ----> 5                         render='matplotlib')
#       6
#       7 cb_flatmap.figure.savefig(data_dir+'/group/tmap_kids_social_facesVoutcm_suit_fdr05_flatmap.png')
#
# /opt/anaconda3/lib/python3.7/site-packages/SUITPy/flatmap.py in plot(data, surf, underlay, undermap, underscale, overlay_type, threshold, cmap, cscale, label_names, borders, bordercolor, bordersize, alpha, render, hover, new_figure, colorbar, cbar_tick_format, backgroundcolor)
#     656                 cbar = _colorbar_label(ax, cmap, cscale, cbar_tick_format, label_names)
#     657             elif overlay_type=='func':
# --> 658                 cbar = _colorbar_func(ax, cmap, cscale, cbar_tick_format)
#     659     elif render == 'plotly':
#     660         if hover == 'auto':
#
# /opt/anaconda3/lib/python3.7/site-packages/SUITPy/flatmap.py in _colorbar_func(ax, cmap, cscale, cbar_tick_format)
#    1003         proxy_mappable, cax=cax, ticks=ticks,
#    1004         boundaries=bounds, spacing='proportional',
# -> 1005         format=cbar_tick_format, orientation='vertical')
#    1006
#    1007     return cbar
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in colorbar(mappable, cax, ax, **kw)
#    2086                                'an image (with imshow) or a contour set ('
#    2087                                'with contourf).')
# -> 2088     ret = gcf().colorbar(mappable, cax=cax, ax=ax, **kw)
#    2089     return ret
#    2090
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in colorbar(self, mappable, cax, ax, use_gridspec, **kw)
#    1156         cb_kw = {k: v for k, v in kw.items() if k not in NON_COLORBAR_KEYS}
#    1157
# -> 1158         cb = cbar.Colorbar(cax, mappable, **cb_kw)
#    1159
#    1160         if not userax:
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/colorbar.py in __init__(self, ax, mappable, cmap, norm, alpha, values, boundaries, orientation, ticklocation, extend, spacing, ticks, format, drawedges, filled, extendfrac, extendrect, label)
#     482
#     483         self.set_label(label)
# --> 484         self._reset_locator_formatter_scale()
#     485
#     486         if np.iterable(ticks):
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/colorbar.py in _reset_locator_formatter_scale(self)
#    1173         the mappable normal gets changed: Colorbar.update_normal)
#    1174         """
# -> 1175         self._process_values()
#    1176         self.locator = None
#    1177         self.minorlocator = None
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/colorbar.py in _process_values(self)
#    1112             self.norm.vmax = 1
#    1113         self.norm.vmin, self.norm.vmax = mtransforms.nonsingular(
# -> 1114             self.norm.vmin, self.norm.vmax, expander=0.1)
#    1115         if (not isinstance(self.norm, colors.BoundaryNorm) and
#    1116                 (self.boundaries is None)):
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py in vmin(self, value)
#    1148         if value != self._vmin:
#    1149             self._vmin = value
# -> 1150             self._changed()
#    1151
#    1152     @property
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py in _changed(self)
#    1176         callback listeners to the 'changed' signal.
#    1177         """
# -> 1178         self.callbacks.process('changed')
#    1179
#    1180     @staticmethod
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in process(self, s, *args, **kwargs)
#     290                 except Exception as exc:
#     291                     if self.exception_handler is not None:
# --> 292                         self.exception_handler(exc)
#     293                     else:
#     294                         raise
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in _exception_printer(exc)
#      94 def _exception_printer(exc):
#      95     if _get_running_interactive_framework() in ["headless", None]:
# ---> 96         raise exc
#      97     else:
#      98         traceback.print_exc()
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in process(self, s, *args, **kwargs)
#     285             if func is not None:
#     286                 try:
# --> 287                     func(*args, **kwargs)
#     288                 # this does not capture KeyboardInterrupt, SystemExit,
#     289                 # and GeneratorExit
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cm.py in changed(self)
#     616         callbackSM listeners to the 'changed' signal.
#     617         """
# --> 618         self.callbacks.process('changed', self)
#     619         self.stale = True
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in process(self, s, *args, **kwargs)
#     290                 except Exception as exc:
#     291                     if self.exception_handler is not None:
# --> 292                         self.exception_handler(exc)
#     293                     else:
#     294                         raise
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in _exception_printer(exc)
#      94 def _exception_printer(exc):
#      95     if _get_running_interactive_framework() in ["headless", None]:
# ---> 96         raise exc
#      97     else:
#      98         traceback.print_exc()
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in process(self, s, *args, **kwargs)
#     285             if func is not None:
#     286                 try:
# --> 287                     func(*args, **kwargs)
#     288                 # this does not capture KeyboardInterrupt, SystemExit,
#     289                 # and GeneratorExit
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/colorbar.py in update_normal(self, mappable)
#     545             self._reset_locator_formatter_scale()
#     546
# --> 547         self.draw_all()
#     548         if isinstance(self.mappable, contour.ContourSet):
#     549             CS = self.mappable
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/colorbar.py in draw_all(self)
#     599             if self._extend_upper():
#     600                 ind = ind[:-1]
# --> 601             self._add_solids(X, Y, self._values[ind, np.newaxis])
#     602
#     603     def _add_solids(self, X, Y, C):
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/colorbar.py in _add_solids(self, X, Y, C)
#     617             self.solids = self.ax.pcolormesh(
#     618                 X, Y, C, cmap=self.cmap, norm=self.norm, alpha=self.alpha,
# --> 619                 edgecolors='none', shading='flat')
#     620             if not self.drawedges:
#     621                 if len(self._y) >= self.n_rasterize:
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in pcolormesh(self, alpha, norm, cmap, vmin, vmax, shading, antialiased, *args, **kwargs)
#    6061
#    6062         X, Y, C, shading = self._pcolorargs('pcolormesh', *args,
# -> 6063                                             shading=shading, kwargs=kwargs)
#    6064         coords = np.stack([X, Y], axis=-1)
#    6065         # convert to one dimensional array
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in _pcolorargs(self, funcname, shading, *args, **kwargs)
#    5539                 if np.ma.is_masked(X) or np.ma.is_masked(Y):
#    5540                     raise ValueError(
# -> 5541                         'x and y arguments to pcolormesh cannot have '
#    5542                         'non-finite values or be of type '
#    5543                         'numpy.ma.core.MaskedArray with masked values')
#
# ValueError: x and y arguments to pcolormesh cannot have non-finite values or be of type numpy.ma.core.MaskedArray with masked values

# %%
funcdata = flatmap.vol_to_surf(data_dir+'/group/tmap_colg_social_facesVoutcm_suit_fdr05.nii.gz')
print('Output is a np.array of size:',funcdata.shape)

cb_flatmap = flatmap.plot(data=funcdata, cmap='coolwarm', \
                        threshold=[0,3], \
                        new_figure=True, \
                        colorbar=True, \
                        render='matplotlib')

cb_flatmap.figure.savefig(data_dir+'/group/tmap_colg_social_facesVoutcm_suit_fdr05_flatmap.png')

cb_flatmap
# Out:
# Output is a np.array of size: (28935, 1)
# <AxesSubplot:>

# %% [markdown]
# # Correct Vs Incorrect

# %%
plot_stat_map(univ_stats_all['kids_mdoors_all_winVlos']['t'].to_nifti(), threshold=3,
    cut_coords=range(-65, 66, 10), display_mode='x', vmax=10, colorbar=True,
    title='Uncorrected')
#plt.savefig(data_dir+'/group/tmap_facesVoutcm_unc.png')

plot_stat_map(univ_stats_all['kids_mdoors_all_winVlos']['thr_t'].to_nifti(), threshold=3,
    cut_coords=range(-65, 66, 10), display_mode='x', vmax=10, colorbar=True,
    title='FDR .05')
#plt.savefig(data_dir+'/group/tmap_faces_outcm_fdr05.png')

# %%
plot_stat_map(univ_stats_all['colg_mdoors_all_winVlos']['t'].to_nifti(), threshold=3,
    cut_coords=range(-65, 66, 10), display_mode='x', vmax=10, colorbar=True,
    title='Uncorrected')
#plt.savefig(data_dir+'/group/tmap_facesVoutcm_unc.png')

plot_stat_map(univ_stats_all['colg_mdoors_all_winVlos']['thr_t'].to_nifti(), threshold=3,
    cut_coords=range(-65, 66, 10), display_mode='x', vmax=10, colorbar=True,
    title='FDR .05')
#plt.savefig(data_dir+'/group/tmap_faces_outcm_fdr05.png')

# %%
plot_stat_map(univ_stats_all['kids_social_all_winVlos']['t'].to_nifti(), threshold=3,
    cut_coords=range(-65, 66, 10), display_mode='x', vmax=10, colorbar=True,
    title='Uncorrected')
#plt.savefig(data_dir+'/group/tmap_facesVoutcm_unc.png')

plot_stat_map(univ_stats_all['kids_social_all_winVlos']['thr_t'].to_nifti(), threshold=3,
    cut_coords=range(-65, 66, 10), display_mode='x', vmax=10, colorbar=True,
    title='FDR .05')
#plt.savefig(data_dir+'/group/tmap_faces_outcm_fdr05.png')

# %%
plot_stat_map(univ_stats_all['colg_social_all_winVlos']['t'].to_nifti(), threshold=3,
    cut_coords=range(-65, 66, 10), display_mode='x', vmax=10, colorbar=True,
    title='Uncorrected')
#plt.savefig(data_dir+'/group/tmap_facesVoutcm_unc.png')

plot_stat_map(univ_stats_all['colg_social_all_winVlos']['thr_t'].to_nifti(), threshold=3,
    cut_coords=range(-65, 66, 10), display_mode='x', vmax=10, colorbar=True,
    title='FDR .05')
#plt.savefig(data_dir+'/group/tmap_faces_outcm_fdr05.png')

# %% [markdown]
# # Positive - Correct vs Incorrect

# %%
plot_stat_map(univ_stats_all['kids_mdoors_positive_winVlos']['t'].to_nifti(), threshold=3,
    cut_coords=range(-65, 66, 10), display_mode='x', vmax=10, colorbar=True,
    title='Uncorrected')
#plt.savefig(data_dir+'/group/tmap_facesVoutcm_unc.png')

plot_stat_map(univ_stats_all['kids_mdoors_positive_winVlos']['thr_t'].to_nifti(), threshold=3,
    cut_coords=range(-65, 66, 10), display_mode='x', vmax=10, colorbar=True,
    title='FDR .05')
#plt.savefig(data_dir+'/group/tmap_faces_outcm_fdr05.png')

# %%
plot_stat_map(univ_stats_all['colg_mdoors_positive_winVlos']['t'].to_nifti(), threshold=3,
    cut_coords=range(-65, 66, 10), display_mode='x', vmax=10, colorbar=True,
    title='Uncorrected')
#plt.savefig(data_dir+'/group/tmap_facesVoutcm_unc.png')

plot_stat_map(univ_stats_all['colg_mdoors_positive_winVlos']['thr_t'].to_nifti(), threshold=3,
    cut_coords=range(-65, 66, 10), display_mode='x', vmax=10, colorbar=True,
    title='FDR .05')
#plt.savefig(data_dir+'/group/tmap_faces_outcm_fdr05.png')

# %%
plot_stat_map(univ_stats_all['kids_social_positive_winVlos']['t'].to_nifti(), threshold=3,
    cut_coords=range(-65, 66, 10), display_mode='x', vmax=10, colorbar=True,
    title='Uncorrected')
#plt.savefig(data_dir+'/group/tmap_facesVoutcm_unc.png')

plot_stat_map(univ_stats_all['kids_social_positive_winVlos']['thr_t'].to_nifti(), threshold=3,
    cut_coords=range(-65, 66, 10), display_mode='x', vmax=10, colorbar=True,
    title='FDR .05')
#plt.savefig(data_dir+'/group/tmap_faces_outcm_fdr05.png')

# %%
plot_stat_map(univ_stats_all['colg_social_positive_winVlos']['t'].to_nifti(), threshold=3,
    cut_coords=range(-65, 66, 10), display_mode='x', vmax=10, colorbar=True,
    title='Uncorrected')
#plt.savefig(data_dir+'/group/tmap_facesVoutcm_unc.png')

plot_stat_map(univ_stats_all['colg_social_positive_winVlos']['thr_t'].to_nifti(), threshold=3,
    cut_coords=range(-65, 66, 10), display_mode='x', vmax=10, colorbar=True,
    title='FDR .05')
#plt.savefig(data_dir+'/group/tmap_faces_outcm_fdr05.png')
