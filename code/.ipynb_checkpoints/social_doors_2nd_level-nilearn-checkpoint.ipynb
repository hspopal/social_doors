# %% [markdown]
# # Social Doors Univariate Second Level Analysis

# %% [markdown]
# ### Setup

# %%
import os
import glob
import pandas as pd
import numpy as np

from matplotlib.gridspec import GridSpec

# Import cerebellum packages
import matplotlib.pyplot as plt
import SUITPy.flatmap as flatmap

from nilearn.glm.second_level import make_second_level_design_matrix
from nilearn.plotting import plot_design_matrix, plot_stat_map
from nilearn.glm.second_level import SecondLevelModel
from nilearn.glm import threshold_stats_img

import importlib

import helpful_functions
importlib.reload(helpful_functions)
# Out:
# <module 'helpful_functions' from '/Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py'>

# %%
#bids_dir = '/data/projects/social_doors/'
bids_dir = '/Volumes/HP-SOC-DOOR/social_doors/'


os.chdir(bids_dir)

data_dir = os.path.join(bids_dir, 'derivatives','social_doors-nilearn')
outp_dir = os.path.join(bids_dir, 'derivatives', 'social_doors-nilearn')


# Define subject list
#subjs_scan_info = pd.read_csv(bids_dir+'/derivatives/mriqc/mriqc_summary_poor.csv')
#subjs_list = list(subjs_scan_info['subject'].unique())
#subjs_list.sort()
subjs_info = pd.read_csv(bids_dir+'/derivatives/participants_good.tsv', sep='\t', index_col=0)
subjs_info = subjs_info.rename(columns={'participant_id': 'subject_label'})

# Remove participants with bad data
subjs_info = subjs_info[subjs_info['subject_label'].str.contains('sub-3880')==False]
subjs_info = subjs_info[subjs_info['subject_label'].str.contains('sub-4069')==False]


subjs_info_kids = subjs_info[subjs_info['group']=='kid']
subjs_info_colg = subjs_info[subjs_info['group']=='college']

subjs_list = subjs_info['subject_label'].to_list()
subjs_list_kids = subjs_info_kids['subject_label'].to_list()
subjs_list_colg = subjs_info_colg['subject_label'].to_list()

print('Found '+str(len(subjs_list_kids))+' adolescent subjects')
print('Found '+str(len(subjs_list_colg))+' college subjects')
# Out:
# Found 32 adolescent subjects
# Found 29 college subjects

# %% [markdown]
# ## Adolescents

# %%
# Filter for releveant data
subjs_info_fltr = subjs_info[['subject_label', 'age']]
subjs_info_kids_fltr = subjs_info_kids[['subject_label','age']]
subjs_info_colg_fltr = subjs_info_colg[['subject_label','age']]

# %%
design_matrix = make_second_level_design_matrix(subjs_list_kids, subjs_info_kids_fltr)

plot_design_matrix(design_matrix)
# Out:
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2464691570.py:1: UserWarning: Attention: Design matrix is singular. Aberrant estimates are expected.
#   design_matrix = make_second_level_design_matrix(subjs_list_kids, subjs_info_kids_fltr)
# <Axes: label='conditions', ylabel='scan number'>

# %%
def calc_second_level(group, subjs_list, task, contrast, contrasts_2nd, space):

    if not space:
        # Collect data in default space
        temp_file_list = []
        for subj in subjs_list:
            temp_file = glob.glob(os.path.join(data_dir,subj,'zmap_'+task+'_'+contrast+'.nii.gz'))
            temp_file_list.append(temp_file[0])
        temp_file_list.sort()

        mask = os.path.join(bids_dir, 'derivatives', 'fmriprep', 'sub-010', 'anat', 
                            'sub-010_space-MNI152NLin2009cAsym_label-GM_probseg_bin.nii.gz')

    
    if space == 'SUIT':
        # Collect cerebellum data in SUIT space
        temp_file_list = []
        for subj in subjs_list:
            temp_file = glob.glob(os.path.join(data_dir,subj,'zmap_'+task+'_'+contrast+'_space-SUIT.nii.gz'))
            if len(temp_file) == 0:
                print(subj)
                print(task)
                print(contrast)
            temp_file_list.append(temp_file[0])
        temp_file_list.sort()

        mask = os.path.join(bids_dir + 'derivatives', 'fmriprep', 'sub-010', 'anat', 
                            'sub-010_run-1_space-MNI152NLin2009cAsym_desc-preproc_T1w_cerebellum_dseg.nii.gz')

        
    print('Calculating '+task+' '+group+' '+contrast+' contrast')
    # Fit the second level GLM
    model = SecondLevelModel(mask_img=mask, smoothing_fwhm=8.0)
    model.fit(temp_file_list, design_matrix=design_matrix)
    
    for contrast_2nd in contrasts_2nd:
        # Compute a specific contrast (e.g. pos reward vs neg reward)
        contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
        
        # Save the z-score stat map and the effect size map
        z_map = contrast_stats['z_score']
        e_map = contrast_stats['effect_size']

        if space == 'SUIT':
            z_map.to_filename(os.path.join(data_dir,'group',
                              group+'_'+task+'_'+contrast+'_'+contrast_2nd+'_zmap_space-SUIT.nii.gz'))
            e_map.to_filename(os.path.join(data_dir,'group',
                              group+'_'+task+'_'+contrast+'_'+contrast_2nd+'_effect_space-SUIT.nii.gz'))
        
            
            # Multiple Comparisons Correction
            z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
            z_map_thresh.to_filename(os.path.join(data_dir,'group',
                                     group+'_'+task+'_'+contrast+'_'+contrast_2nd+'_zmap_'+mc+'-'+str(alpha)+'_space-SUIT.nii.gz'))

        else:
            z_map.to_filename(os.path.join(data_dir,'group',
                              group+'_'+task+'_'+contrast+'_'+contrast_2nd+'_zmap.nii.gz'))
            e_map.to_filename(os.path.join(data_dir,'group',
                              group+'_'+task+'_'+contrast+'_'+contrast_2nd+'_effect.nii.gz'))
        
            
            # Multiple Comparisons Correction
            z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
            z_map_thresh.to_filename(os.path.join(data_dir,'group',
                                     group+'_'+task+'_'+contrast+'_'+contrast_2nd+'_zmap_'+mc+'-'+str(alpha)+'.nii.gz'))

# %%
design_matrix = make_second_level_design_matrix(subjs_list_kids, subjs_info_kids_fltr)

#contrasts = ['valence_x_outcome',
#             'positive','positive_win','positive_loss',
#             'negative','negative_win','negative_loss']
contrasts = ['positive_winVlos', 'negative_winVlos', 'posVneg_win', 'all_winVlos']
contrasts_2nd = ['age','intercept']
tasks = ['mdoors','social']
group = 'adole'
mc = 'fdr'
alpha = 0.05


for task in tasks:
    for contrast in contrasts:
            
        calc_second_level(group='adole', subjs_list=subjs_list_kids, task=task, 
                          contrast=contrast, contrasts_2nd=contrasts_2nd, space=None)
    
        calc_second_level(group='adole', subjs_list=subjs_list_kids, task=task, 
                          contrast=contrast, contrasts_2nd=contrasts_2nd, space='SUIT')
# Out:
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2844014471.py:1: UserWarning: Attention: Design matrix is singular. Aberrant estimates are expected.
#   design_matrix = make_second_level_design_matrix(subjs_list_kids, subjs_info_kids_fltr)
# Calculating mdoors adole positive_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.2996743343642176. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.5154294994748265. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating mdoors adole positive_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 2.8929502960119233. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 3.1069332040486515. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating mdoors adole negative_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.6910804895486247. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.6748403310521525. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating mdoors adole negative_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 2.72520231125106. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 2.671150364173866. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating mdoors adole posVneg_win contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.790218109474217. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.760245567689896. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating mdoors adole posVneg_win contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 3.876642191373018. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 3.8630923703768527. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating mdoors adole all_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 4.580290274860726. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 4.526642761939782. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating mdoors adole all_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 3.0213616622241504. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 3.1025378678660562. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating social adole positive_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.422291396341851. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.5361947794191595. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating social adole positive_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 2.904679333519658. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 2.9088764824761983. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating social adole negative_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.6837590283733133. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.694126075764146. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating social adole negative_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 3.796481563199291. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 3.865744522429885. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating social adole posVneg_win contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.9053348467187523. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.7424756140347215. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating social adole posVneg_win contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 3.5028458154433184. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 3.499760680230122. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating social adole all_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 4.339651990140702. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 4.382061780412051. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating social adole all_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 4.366466511409719. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 4.430503653341183. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)

# %% [markdown]
# ### Monetary Task

# %% [markdown]
# #### Positive win > Positive loss

# %%
filename = data_dir+'/group/'+'adole_mdoors_positive_winVlos_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: empty mask
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: kwargs['alpha']=1 detected in parameters.
# Overriding with transparency=None.
# To suppress this warning pass your 'alpha' value via the 'transparency' parameter.
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],

# %% [markdown]
# #### All wins > All losses

# %%
filename = data_dir+'/group/'+'adole_mdoors_all_winVlos_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: empty mask
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: kwargs['alpha']=1 detected in parameters.
# Overriding with transparency=None.
# To suppress this warning pass your 'alpha' value via the 'transparency' parameter.
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],

# %% [markdown]
# #### Positive wins > Negative wins

# %%
filename = data_dir+'/group/'+'adole_mdoors_posVneg_win_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: empty mask
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: kwargs['alpha']=1 detected in parameters.
# Overriding with transparency=None.
# To suppress this warning pass your 'alpha' value via the 'transparency' parameter.
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],

# %% [markdown]
# ### Social Task

# %% [markdown]
# #### Positive win > Positive loss

# %%
filename = data_dir+'/group/'+'adole_social_positive_winVlos_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: empty mask
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: kwargs['alpha']=1 detected in parameters.
# Overriding with transparency=None.
# To suppress this warning pass your 'alpha' value via the 'transparency' parameter.
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],

# %% [markdown]
# #### All wins > All losses

# %%
filename = data_dir+'/group/'+'adole_social_all_winVlos_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: empty mask
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: kwargs['alpha']=1 detected in parameters.
# Overriding with transparency=None.
# To suppress this warning pass your 'alpha' value via the 'transparency' parameter.
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],

# %% [markdown]
# #### Positive wins > Negative wins

# %%
filename = data_dir+'/group/'+'adole_social_posVneg_win_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: empty mask
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: kwargs['alpha']=1 detected in parameters.
# Overriding with transparency=None.
# To suppress this warning pass your 'alpha' value via the 'transparency' parameter.
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],

# %% [markdown]
# ## Young Adult Cohort

# %%
# Filter for releveant data
subjs_info_fltr = subjs_info[['subject_label', 'age']]
subjs_info_kids_fltr = subjs_info_kids[['subject_label','age']]
subjs_info_colg_fltr = subjs_info_colg[['subject_label','age']]

# %%
design_matrix = make_second_level_design_matrix(subjs_list_colg, subjs_info_colg_fltr)

#contrasts = ['valence_x_outcome',
#             'positive','positive_win','positive_loss',
#             'negative','negative_win','negative_loss']
contrasts = ['positive_winVlos', 'negative_winVlos', 'posVneg_win', 'all_winVlos']
contrasts_2nd = ['age','intercept']
tasks = ['mdoors','social']
group = 'adult'
mc = 'fdr'
alpha = 0.05


for task in tasks:
    for contrast in contrasts:
            
        calc_second_level(group='adult', subjs_list=subjs_list_colg, task=task, 
                          contrast=contrast, contrasts_2nd=contrasts_2nd, space=None)
    
        calc_second_level(group='adult', subjs_list=subjs_list_colg, task=task, 
                          contrast=contrast, contrasts_2nd=contrasts_2nd, space='SUIT')
# Out:
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/562289475.py:1: UserWarning: Attention: Design matrix is singular. Aberrant estimates are expected.
#   design_matrix = make_second_level_design_matrix(subjs_list_colg, subjs_info_colg_fltr)
# Calculating mdoors adult positive_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.677621869947795. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.613809977625141. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating mdoors adult positive_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 4.71193731654288. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 4.552546114128875. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating mdoors adult negative_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 4.808988167371915. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 4.525674522973027. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating mdoors adult negative_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 4.036163296306713. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 3.8290871644807902. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating mdoors adult posVneg_win contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.1330590070756026. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.3116894852284418. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating mdoors adult posVneg_win contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 2.8782559876732474. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 2.623460407234529. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating mdoors adult all_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 4.39749919723207. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 4.317842752894569. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating mdoors adult all_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 4.42117269799632. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 4.257757728446487. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating social adult positive_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.970828490447888. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.494176493951313. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating social adult positive_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# Calculating social adult negative_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.7837725011651413. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.5624796599016277. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating social adult negative_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 4.686433258789298. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 4.609544266242264. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating social adult posVneg_win contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.5439406358711003. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.57074974175218. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating social adult posVneg_win contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 4.372614430770845. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 4.223941395211021. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating social adult all_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 4.289643760859851. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 4.045617924885989. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating social adult all_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')

# %% [markdown]
# ### Monetary Task

# %% [markdown]
# #### Positive win > Positive loss

# %%
filename = data_dir+'/group/'+'adult_mdoors_positive_winVlos_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: empty mask
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: kwargs['alpha']=1 detected in parameters.
# Overriding with transparency=None.
# To suppress this warning pass your 'alpha' value via the 'transparency' parameter.
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],

# %% [markdown]
# #### All wins > All losses

# %%
filename = data_dir+'/group/'+'adult_mdoors_all_winVlos_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: empty mask
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: kwargs['alpha']=1 detected in parameters.
# Overriding with transparency=None.
# To suppress this warning pass your 'alpha' value via the 'transparency' parameter.
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],

# %% [markdown]
# #### Positive wins > Negative wins

# %%
filename = data_dir+'/group/'+'adult_mdoors_posVneg_win_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: empty mask
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: kwargs['alpha']=1 detected in parameters.
# Overriding with transparency=None.
# To suppress this warning pass your 'alpha' value via the 'transparency' parameter.
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],

# %% [markdown]
# ### Social Task

# %% [markdown]
# #### Positive win > Positive loss

# %%
filename = data_dir+'/group/'+'adult_social_positive_winVlos_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: empty mask
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: kwargs['alpha']=1 detected in parameters.
# Overriding with transparency=None.
# To suppress this warning pass your 'alpha' value via the 'transparency' parameter.
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],

# %% [markdown]
# #### All wins > All losses

# %%
filename = data_dir+'/group/'+'adult_social_all_winVlos_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: empty mask
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: kwargs['alpha']=1 detected in parameters.
# Overriding with transparency=None.
# To suppress this warning pass your 'alpha' value via the 'transparency' parameter.
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],

# %% [markdown]
# ### Positive wins > Negative wins

# %%
filename = data_dir+'/group/'+'adult_social_posVneg_win_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: empty mask
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: kwargs['alpha']=1 detected in parameters.
# Overriding with transparency=None.
# To suppress this warning pass your 'alpha' value via the 'transparency' parameter.
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],

# %% [markdown]
# # All Subjects

# %%
subjs_info_num = subjs_info.copy()
subjs_info_num = subjs_info_num.replace({'sex': {'F': 0, 'M': 1},
                                         'group': {'college': -1, 'kid': 1}})
subjs_info_num = subjs_info_num.drop(columns=['age', 'sex'])

design_matrix = make_second_level_design_matrix(subjs_list, subjs_info_num)

plot_design_matrix(design_matrix)
# Out:
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/4178790924.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   subjs_info_num = subjs_info_num.replace({'sex': {'F': 0, 'M': 1},
# <Axes: label='conditions', ylabel='scan number'>

# %%
contrasts = ['positive_winVlos', 'negative_winVlos', 'posVneg_win', 'all_winVlos']
contrasts_2nd = ['group','intercept']
tasks = ['mdoors','social']
group = 'all'
mc = 'fdr'
alpha = 0.05


for task in tasks:
    for contrast in contrasts:
            
        calc_second_level(group=group, subjs_list=subjs_list, task=task, 
                          contrast=contrast, contrasts_2nd=contrasts_2nd, space=None)
    
        calc_second_level(group=group, subjs_list=subjs_list, task=task, 
                          contrast=contrast, contrasts_2nd=contrasts_2nd, space='SUIT')
# Out:
# Calculating mdoors all positive_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.633481036206817. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating mdoors all positive_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 3.2137500519729585. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 3.815966784223071. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating mdoors all negative_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.3870248143232904. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating mdoors all negative_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 2.9393246984432118. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 3.439046673534666. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating mdoors all posVneg_win contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.795875052485571. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 4.222071420771786. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating mdoors all posVneg_win contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 3.6067768158258606. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 3.2201704011117345. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating mdoors all all_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.5505066649097126. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating mdoors all all_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 3.0173548122957614. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 2.4735709026589143. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating social all positive_winVlos contrast
# Calculating social all positive_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 3.2513597715191747. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# Calculating social all negative_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.3597512508322116. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating social all negative_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 2.3193041036998556. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 3.617731858706427. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating social all posVneg_win contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.5118408411857702. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.742242724762431. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating social all posVneg_win contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 3.336953248884221. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 3.3879565178370634. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating social all all_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.782232269300627. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating social all all_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 2.876216217835345. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')

# %% [markdown]
# ## Group differences
# Where adolescents > young adults

# %% [markdown]
# ### Monetary Task

# %% [markdown]
# #### Positive win > Positive loss

# %%
filename = data_dir+'/group/'+'all_mdoors_positive_winVlos_group'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: empty mask
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: kwargs['alpha']=1 detected in parameters.
# Overriding with transparency=None.
# To suppress this warning pass your 'alpha' value via the 'transparency' parameter.
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],

# %% [markdown]
# #### All wins > All losses

# %%
filename = data_dir+'/group/'+'all_mdoors_all_winVlos_group'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: empty mask
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: kwargs['alpha']=1 detected in parameters.
# Overriding with transparency=None.
# To suppress this warning pass your 'alpha' value via the 'transparency' parameter.
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],

# %% [markdown]
# ### Positive win > Negative win

# %%
filename = data_dir+'/group/'+'all_mdoors_posVneg_win_group'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: empty mask
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: kwargs['alpha']=1 detected in parameters.
# Overriding with transparency=None.
# To suppress this warning pass your 'alpha' value via the 'transparency' parameter.
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],

# %% [markdown]
# ### Social Task

# %% [markdown]
# #### Positive win > Positive loss

# %%
filename = data_dir+'/group/'+'all_social_positive_winVlos_group'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: kwargs['alpha']=1 detected in parameters.
# Overriding with transparency=None.
# To suppress this warning pass your 'alpha' value via the 'transparency' parameter.
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],

# %% [markdown]
# #### All wins > All losses

# %%
filename = data_dir+'/group/'+'all_social_all_winVlos_group'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: empty mask
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: kwargs['alpha']=1 detected in parameters.
# Overriding with transparency=None.
# To suppress this warning pass your 'alpha' value via the 'transparency' parameter.
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],

# %% [markdown]
# ### Positive win > Negative win

# %%
filename = data_dir+'/group/'+'all_social_posVneg_win_group'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: empty mask
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: kwargs['alpha']=1 detected in parameters.
# Overriding with transparency=None.
# To suppress this warning pass your 'alpha' value via the 'transparency' parameter.
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],

# %% [markdown]
# ## Accounting for Group

# %% [markdown]
# ### Monetary Task

# %% [markdown]
# #### Positive win > Positive loss

# %%
filename = data_dir+'/group/'+'all_mdoors_positive_winVlos_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: kwargs['alpha']=1 detected in parameters.
# Overriding with transparency=None.
# To suppress this warning pass your 'alpha' value via the 'transparency' parameter.
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],

# %% [markdown]
# #### All wins > All losses

# %%
filename = data_dir+'/group/'+'all_mdoors_all_winVlos_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: kwargs['alpha']=1 detected in parameters.
# Overriding with transparency=None.
# To suppress this warning pass your 'alpha' value via the 'transparency' parameter.
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],

# %% [markdown]
# ### Positive win > Negative win

# %%
filename = data_dir+'/group/'+'all_mdoors_posVneg_win_group'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: empty mask
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: kwargs['alpha']=1 detected in parameters.
# Overriding with transparency=None.
# To suppress this warning pass your 'alpha' value via the 'transparency' parameter.
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],

# %% [markdown]
# ### Social Task

# %% [markdown]
# #### Positive wins > Positive losses

# %%
filename = data_dir+'/group/'+'all_social_positive_winVlos_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: kwargs['alpha']=1 detected in parameters.
# Overriding with transparency=None.
# To suppress this warning pass your 'alpha' value via the 'transparency' parameter.
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],

# %% [markdown]
# #### All wins > All losses

# %%
filename = data_dir+'/group/'+'all_social_all_winVlos_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: kwargs['alpha']=1 detected in parameters.
# Overriding with transparency=None.
# To suppress this warning pass your 'alpha' value via the 'transparency' parameter.
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],

# %% [markdown]
# ### Positive win > Negative win

# %%
filename = data_dir+'/group/'+'all_social_posVneg_win_group'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: empty mask
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: kwargs['alpha']=1 detected in parameters.
# Overriding with transparency=None.
# To suppress this warning pass your 'alpha' value via the 'transparency' parameter.
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],

# %% [markdown]
# ## Accounting for Age

# %%
subjs_info_num = subjs_info.copy()
subjs_info_num = subjs_info_num.replace({'sex': {'F': 0, 'M': 1},
                                         'group': {'college': -1, 'kid': 1}})
subjs_info_num = subjs_info_num.drop(columns=['group','sex'])

design_matrix = make_second_level_design_matrix(subjs_list, subjs_info_num)

plot_design_matrix(design_matrix)
# Out:
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/3157774009.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   subjs_info_num = subjs_info_num.replace({'sex': {'F': 0, 'M': 1},
# <Axes: label='conditions', ylabel='scan number'>

# %%
contrasts = ['positive_winVlos', 'negative_winVlos', 'posVneg_win', 'all_winVlos']
contrasts_2nd = ['age','intercept']
tasks = ['mdoors','social']
group = 'all'
mc = 'fdr'
alpha = 0.05


for task in tasks:
    for contrast in contrasts:
            
        calc_second_level(group=group, subjs_list=subjs_list, task=task, 
                          contrast=contrast, contrasts_2nd=contrasts_2nd, space=None)
    
        calc_second_level(group=group, subjs_list=subjs_list, task=task, 
                          contrast=contrast, contrasts_2nd=contrasts_2nd, space='SUIT')
# Out:
# Calculating mdoors all positive_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.9701748469025335. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 4.452501132383584. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating mdoors all positive_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 3.6897787334296708. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 3.917347631309868. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating mdoors all negative_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 4.280403998404074. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 4.411787718513701. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating mdoors all negative_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 3.355147597293726. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 3.32236409080263. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating mdoors all posVneg_win contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.910423113493265. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 4.110464739033102. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating mdoors all posVneg_win contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 4.248948339468039. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 4.352819137303001. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating mdoors all all_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.6134552453595408. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.6644795032426405. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating mdoors all all_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 2.503427169183843. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 2.527722972435203. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating social all positive_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 4.163235479304502. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 4.382637118728304. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating social all positive_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 2.8601821140014545. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 3.285983448583689. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating social all negative_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.115772176781927. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.2179945937494434. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating social all negative_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 3.4647113875186677. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 3.1150509203082883. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating social all posVneg_win contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 4.043602540183166. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 4.111362507279355. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating social all posVneg_win contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 2.919953121299921. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 2.9502066033171097. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating social all all_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 3.8393277493135525. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:64: UserWarning: The given float value must not exceed 4.169740915027432. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# Calculating social all all_winVlos contrast
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 3.1045205723660576. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:38: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2612186938.py:52: UserWarning: The given float value must not exceed 3.651451549264967. But, you have given threshold=inf.
#   z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)

# %% [markdown]
# ### Monetary Task

# %%
filename = data_dir+'/group/'+'all_mdoors_positive_winVlos_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: empty mask
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: kwargs['alpha']=1 detected in parameters.
# Overriding with transparency=None.
# To suppress this warning pass your 'alpha' value via the 'transparency' parameter.
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],

# %%
filename = data_dir+'/group/'+'all_mdoors_posVneg_win_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: empty mask
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],
# /Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py:48: UserWarning: kwargs['alpha']=1 detected in parameters.
# Overriding with transparency=None.
# To suppress this warning pass your 'alpha' value via the 'transparency' parameter.
#   hemi_lh.add_contours(stat_filename_mc, levels=[-0.1,0.1], colors=['blue','red'],

# %% [markdown]
# ### Social Task

# %% [markdown]
# # Behavioral Analysis
#
# Not updated

# %%
behav_data = pd.read_excel(bids_dir+'/derivatives/behavioral/aggregate_full_data_SPSS_020419.xlsx',
                          sheet_name='Sheet1')

behav_data.head()
# Out:
#    Order Subject  ch_totanx  ch_socialanx  p_totanx  p_socialanx  bfne  \
# 0      1    s010         51            14         7            1    33
# 1      1    s011         12             3         4            1    31
# 2      1    s013          8             4         1            1    13
# 3      1    s015         18             5         1            0    21
# 4      2    s024         21            10         0            0    28
#
#    ch_cdi_total  ch_cdi_interpersonal  ch_cdi_anhedonia  ...  \
# 0          11.0                   0.0               5.0  ...
# 1           8.0                   0.0               3.0  ...
# 2           5.0                   0.0               2.0  ...
# 3           NaN                   NaN               NaN  ...
# 4           1.0                   0.0               0.0  ...
#
#    FB_VS_6mm_R_Like_Lose_NZMean_1  FB_VS_6mm_R_Like_Lose_NZCount_1  \
# 0                        0.029036                            123.0
# 1                             NaN                              NaN
# 2                       -0.308424                            123.0
# 3                       -0.798996                            123.0
# 4                             NaN                              NaN
#
#    FB_VS_6mm_R_Like_Lose_NZMin_1  FB_VS_6mm_R_Like_Lose_NZMax_1  \
# 0                      -0.296210                       0.647286
# 1                            NaN                            NaN
# 2                      -0.554069                       0.030482
# 3                      -1.841710                      -0.031699
# 4                            NaN                            NaN
#
#   FB_VS_6mm_R_Like_Win_Mean_1  FB_VS_6mm_R_Like_Win_NZMean_1  \
# 0                    0.256033                       0.256033
# 1                         NaN                            NaN
# 2                    0.093248                       0.093248
# 3                    0.004660                       0.004660
# 4                         NaN                            NaN
#
#    FB_VS_6mm_R_Like_Win_NZCount_1  FB_VS_6mm_R_Like_Win_NZMin_1  \
# 0                           123.0                     -0.022722
# 1                             NaN                           NaN
# 2                           123.0                     -0.183241
# 3                           123.0                     -1.020790
# 4                             NaN                           NaN
#
#    FB_VS_6mm_R_Like_Win_NZMax_1  FB_VS6mm_L_Correct_DislikeVsLike
# 0                      0.752379                         -0.127002
# 1                           NaN                               NaN
# 2                      1.003483                         -0.167305
# 3                      0.809193                          0.485397
# 4                           NaN                               NaN
#
# [5 rows x 1551 columns]

# %%
behav_data_fltr = behav_data[['Subject','ch_totanx', 'ch_cdi_total']]

behav_data_fltr['Subject'] = behav_data_fltr['Subject'].str.replace('s','sub-')

behav_data_fltr = behav_data_fltr.rename(columns={'Subject':'subject_label'})

behav_data_fltr.head()
# Out:
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/2190512267.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   behav_data_fltr['Subject'] = behav_data_fltr['Subject'].str.replace('s','sub-')
#   subject_label  ch_totanx  ch_cdi_total
# 0       sub-010         51          11.0
# 1       sub-011         12           8.0
# 2       sub-013          8           5.0
# 3       sub-015         18           NaN
# 4       sub-024         21           1.0

# %%
# Add behavioral data to design matrix

subjs_info_kids_behav = subjs_info_kids_fltr.merge(behav_data_fltr, on='subject_label')


design_matrix = make_second_level_design_matrix(subjs_list_kids, subjs_info_kids_behav)

plot_design_matrix(design_matrix)
# Out:
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_3208/1940393905.py:6: UserWarning: Attention: Design matrix is singular. Aberrant estimates are expected.
#   design_matrix = make_second_level_design_matrix(subjs_list_kids, subjs_info_kids_behav)
# <Axes: label='conditions', ylabel='scan number'>

# %%
#design_matrix = make_second_level_design_matrix(subjs_list_kids, subjs_info_kids_fltr)
mni_mask = bids_dir+"/derivatives/fmriprep/sub-010/anat/sub-010_space-MNI152NLin2009cAsym_label-GM_probseg_bin.nii.gz"

#contrasts = ['valence_x_outcome',
#             'positive','positive_win','positive_loss',
#             'negative','negative_win','negative_loss']
contrasts=['all_winVlos', 'positive_winVlos']
contrasts_2nd = ['ch_totanx','ch_cdi_total']
tasks = ['mdoors','social']
group = 'kids'
alpha = 0.001


threshold_data = {}

for task in tasks:
    for contrast in contrasts:
        
        temp_file_list = []
        for subj in subjs_list_kids:
            temp_file = glob.glob(os.path.join(data_dir,subj,'zmap_'+task+'_'+contrast+'.nii'))
            temp_file_list.append(temp_file[0])
        temp_file_list.sort()
        
        print('Calculating '+task+' group '+contrast+' contrast')
        
        model = SecondLevelModel(mask_img=mni_mask, smoothing_fwhm=8.0)
        model.fit(temp_file_list, design_matrix=design_matrix)
        
        for contrast_2nd in contrasts_2nd:
            z_map = model.compute_contrast(contrast_2nd, output_type='z_score')

            z_map.to_filename(os.path.join(data_dir,'group',
                                       'zmap_'+group+'_'+task+'_'+contrast+'_'+contrast_2nd+'_unc.nii.gz'))
            
            # Multiple Comparisons Correction
            z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control='fpr')
            z_map_thresh.to_filename(os.path.join(data_dir,'group',
                                       'zmap_'+group+'_'+task+'_'+contrast+'_'+contrast_2nd+'_fpr.nii.gz'))
            
            threshold_data['zmap_'+group+'_'+task+'_'+contrast+'_'+contrast_2nd+'_fpr_'+str(alpha)] = threshold
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[38], line 22
#      20 for subj in subjs_list_kids:
#      21     temp_file = glob.glob(os.path.join(data_dir,subj,'zmap_'+task+'_'+contrast+'.nii'))
# ---> 22     temp_file_list.append(temp_file[0])
#      23 temp_file_list.sort()
#      25 print('Calculating '+task+' group '+contrast+' contrast')
#
# IndexError: list index out of range

# %%
filename = 'zmap_kids_social_positive_winVlos_ch_cdi_total_'
threshold = threshold_data[filename+'fpr_'+str(alpha)]
#threshold=1

plot_stat_map_cb(filename+'unc', threshold)

# %%
filename = 'zmap_kids_social_all_winVlos_ch_cdi_total_'
threshold = threshold_data[filename+'fpr_'+str(alpha)]
#threshold=1

plot_stat_map_cb(filename+'unc', threshold)
