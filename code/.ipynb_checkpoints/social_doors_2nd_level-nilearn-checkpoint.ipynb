# %% [markdown]
# # Social Doors Univariate Second Level Analysis

# %% [markdown]
# ### Setup

# %%
import os
import glob
import pandas as pd
import numpy as np

from matplotlib.gridspec import GridSpec

# Import cerebellum packages
import matplotlib.pyplot as plt
import SUITPy.flatmap as flatmap

from nilearn.glm.second_level import make_second_level_design_matrix
from nilearn.plotting import plot_design_matrix, plot_stat_map
from nilearn.glm.second_level import SecondLevelModel
from nilearn.glm import threshold_stats_img

import importlib

import helpful_functions
importlib.reload(helpful_functions)
# Out:
# <module 'helpful_functions' from '/Volumes/HP-SOC-DOOR/social_doors/code/helpful_functions.py'>

# %%
#bids_dir = '/data/projects/social_doors/'
bids_dir = '/Volumes/HP-SOC-DOOR/social_doors/'


os.chdir(bids_dir)

data_dir = os.path.join(bids_dir, 'derivatives','social_doors-nilearn')
outp_dir = os.path.join(bids_dir, 'derivatives', 'social_doors-nilearn')


# Define subject list
#subjs_scan_info = pd.read_csv(bids_dir+'/derivatives/mriqc/mriqc_summary_poor.csv')
#subjs_list = list(subjs_scan_info['subject'].unique())
#subjs_list.sort()
subjs_info = pd.read_csv(bids_dir+'/derivatives/participants_good.tsv', sep='\t', index_col=0)
subjs_info = subjs_info.rename(columns={'participant_id': 'subject_label'})

# Remove participants with bad data
subjs_info = subjs_info[subjs_info['subject_label'].str.contains('sub-3880')==False]
subjs_info = subjs_info[subjs_info['subject_label'].str.contains('sub-4069')==False]


subjs_info_kids = subjs_info[subjs_info['group']=='kid']
subjs_info_colg = subjs_info[subjs_info['group']=='college']

subjs_list = subjs_info['subject_label'].to_list()
subjs_list_kids = subjs_info_kids['subject_label'].to_list()
subjs_list_colg = subjs_info_colg['subject_label'].to_list()

print('Found '+str(len(subjs_list_kids))+' adolescent subjects')
print('Found '+str(len(subjs_list_colg))+' college subjects')
# Out:
# Found 32 adolescent subjects
# Found 29 college subjects

# %% [markdown]
# ## Adolescents

# %%
# Filter for releveant data
subjs_info_fltr = subjs_info[['subject_label', 'age']]
subjs_info_kids_fltr = subjs_info_kids[['subject_label','age']]
subjs_info_colg_fltr = subjs_info_colg[['subject_label','age']]

# %%
design_matrix = make_second_level_design_matrix(subjs_list_kids, subjs_info_kids_fltr)

plot_design_matrix(design_matrix)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/first_level/design_matrix.py:531: UserWarning: Attention: Design matrix is singular. Aberrant estimates are expected.
#   warn(
# <Axes: label='conditions', ylabel='scan number'>

# %%
def calc_second_level(group, subjs_list, task, contrast, contrasts_2nd, space):

    if not space:
        # Collect data in default space
        temp_file_list = []
        for subj in subjs_list:
            temp_file = glob.glob(os.path.join(data_dir,subj,'zmap_'+task+'_'+contrast+'.nii.gz'))
            temp_file_list.append(temp_file[0])
        temp_file_list.sort()

        mask = os.path.join(bids_dir, 'derivatives', 'fmriprep', 'sub-010', 'anat', 
                            'sub-010_space-MNI152NLin2009cAsym_label-GM_probseg_bin.nii.gz')

    
    if space == 'SUIT':
        # Collect cerebellum data in SUIT space
        temp_file_list = []
        for subj in subjs_list:
            temp_file = glob.glob(os.path.join(data_dir,subj,'zmap_'+task+'_'+contrast+'_space-SUIT.nii.gz'))
            if len(temp_file) == 0:
                print(subj)
                print(task)
                print(contrast)
            temp_file_list.append(temp_file[0])
        temp_file_list.sort()

        mask = os.path.join(bids_dir + 'derivatives', 'fmriprep', 'sub-010', 'anat', 
                            'sub-010_run-1_space-MNI152NLin2009cAsym_desc-preproc_T1w_cerebellum_dseg.nii.gz')

        
    print('Calculating '+task+' '+group+' '+contrast+' contrast')
    # Fit the second level GLM
    model = SecondLevelModel(mask_img=mask, smoothing_fwhm=8.0)
    model.fit(temp_file_list, design_matrix=design_matrix)
    
    for contrast_2nd in contrasts_2nd:
        # Compute a specific contrast (e.g. pos reward vs neg reward)
        contrast_stats = model.compute_contrast(contrast_2nd, output_type='all')
        
        # Save the z-score stat map and the effect size map
        z_map = contrast_stats['z_score']
        e_map = contrast_stats['effect_size']

        if space == 'SUIT':
            z_map.to_filename(os.path.join(data_dir,'group',
                              group+'_'+task+'_'+contrast+'_'+contrast_2nd+'_zmap_space-SUIT.nii.gz'))
            e_map.to_filename(os.path.join(data_dir,'group',
                              group+'_'+task+'_'+contrast+'_'+contrast_2nd+'_effect_space-SUIT.nii.gz'))
        
            
            # Multiple Comparisons Correction
            z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
            z_map_thresh.to_filename(os.path.join(data_dir,'group',
                                     group+'_'+task+'_'+contrast+'_'+contrast_2nd+'_zmap_'+mc+'-'+str(alpha)+'_space-SUIT.nii.gz'))

        else:
            z_map.to_filename(os.path.join(data_dir,'group',
                              group+'_'+task+'_'+contrast+'_'+contrast_2nd+'_zmap.nii.gz'))
            e_map.to_filename(os.path.join(data_dir,'group',
                              group+'_'+task+'_'+contrast+'_'+contrast_2nd+'_effect.nii.gz'))
        
            
            # Multiple Comparisons Correction
            z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control=mc)
            z_map_thresh.to_filename(os.path.join(data_dir,'group',
                                     group+'_'+task+'_'+contrast+'_'+contrast_2nd+'_zmap_'+mc+'-'+str(alpha)+'.nii.gz'))

# %%
design_matrix = make_second_level_design_matrix(subjs_list_kids, subjs_info_kids_fltr)

#contrasts = ['valence_x_outcome',
#             'positive','positive_win','positive_loss',
#             'negative','negative_win','negative_loss']
contrasts = ['positive_winVlos', 'negative_winVlos', 'posVneg_win', 'all_winVlos']
contrasts_2nd = ['age','intercept']
tasks = ['mdoors','social']
group = 'adole'
mc = 'fdr'
alpha = 0.05


for task in tasks:
    for contrast in contrasts:
            
        calc_second_level(group='adole', subjs_list=subjs_list_kids, task=task, 
                          contrast=contrast, contrasts_2nd=contrasts_2nd, space=None)
    
        calc_second_level(group='adole', subjs_list=subjs_list_kids, task=task, 
                          contrast=contrast, contrasts_2nd=contrasts_2nd, space='SUIT')
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/first_level/design_matrix.py:531: UserWarning: Attention: Design matrix is singular. Aberrant estimates are expected.
#   warn(
# Calculating mdoors adole positive_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.391055283105991. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.645106540276601. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating mdoors adole positive_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.2184216770522265. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.354841892915917. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating mdoors adole negative_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.745467545474631. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.7325800716444726. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating mdoors adole negative_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 2.8192778853324754. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 2.6995274075114724. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating mdoors adole posVneg_win contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 4.03608553917312. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 4.16985662542101. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating mdoors adole posVneg_win contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.910594028523589. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.9541477839345127. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating mdoors adole all_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 4.6821361953459935. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 4.629518766781789. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating mdoors adole all_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.1522407359440527. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.1987135450573425. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating social adole positive_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.421608200670099. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.538984064627074. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating social adole positive_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 2.5039976048334576. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 2.714675356468021. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating social adole negative_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.6753556091423727. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.754334941768756. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating social adole negative_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.4833051686335277. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.5673250519066997. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating social adole posVneg_win contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.864054430927257. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.8849592284868146. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating social adole posVneg_win contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.8964713383674323. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.867815339312791. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating social adole all_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 4.208911757573842. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 4.397953542930391. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating social adole all_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 4.358294590419665. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 4.432208210016206. But, you have given threshold=inf.
#   stat_img = threshold_img(

# %% [markdown]
# ### Monetary Task

# %% [markdown]
# #### Positive win > Positive loss

# %%
filename = data_dir+'/group/'+'adole_mdoors_positive_winVlos_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)

# %% [markdown]
# #### All wins > All losses

# %%
filename = data_dir+'/group/'+'adole_mdoors_all_winVlos_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)

# %% [markdown]
# #### Positive wins > Negative wins

# %%
filename = data_dir+'/group/'+'adole_mdoors_posVneg_win_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)

# %% [markdown]
# ### Social Task

# %% [markdown]
# #### Positive win > Positive loss

# %%
filename = data_dir+'/group/'+'adole_social_positive_winVlos_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)

# %% [markdown]
# #### All wins > All losses

# %%
filename = data_dir+'/group/'+'adole_social_all_winVlos_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)

# %% [markdown]
# #### Positive wins > Negative wins

# %%
filename = data_dir+'/group/'+'adole_social_posVneg_win_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)

# %% [markdown]
# ## Young Adult Cohort

# %%
# Filter for releveant data
subjs_info_fltr = subjs_info[['subject_label', 'age']]
subjs_info_kids_fltr = subjs_info_kids[['subject_label','age']]
subjs_info_colg_fltr = subjs_info_colg[['subject_label','age']]

# %%
design_matrix = make_second_level_design_matrix(subjs_list_colg, subjs_info_colg_fltr)

#contrasts = ['valence_x_outcome',
#             'positive','positive_win','positive_loss',
#             'negative','negative_win','negative_loss']
contrasts = ['positive_winVlos', 'negative_winVlos', 'posVneg_win', 'all_winVlos']
contrasts_2nd = ['age','intercept']
tasks = ['mdoors','social']
group = 'adult'
mc = 'fdr'
alpha = 0.05


for task in tasks:
    for contrast in contrasts:
            
        calc_second_level(group='adult', subjs_list=subjs_list_colg, task=task, 
                          contrast=contrast, contrasts_2nd=contrasts_2nd, space=None)
    
        calc_second_level(group='adult', subjs_list=subjs_list_colg, task=task, 
                          contrast=contrast, contrasts_2nd=contrasts_2nd, space='SUIT')
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/first_level/design_matrix.py:531: UserWarning: Attention: Design matrix is singular. Aberrant estimates are expected.
#   warn(
# Calculating mdoors adult positive_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.5620127303725417. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.6473746572040584. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating mdoors adult positive_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 4.700513994217738. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 4.589390284531663. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating mdoors adult negative_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 4.499487578122588. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 4.2627054587622055. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating mdoors adult negative_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.5433146534124718. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.533711372565382. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating mdoors adult posVneg_win contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.2659570116983665. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.235740169248205. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating mdoors adult posVneg_win contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.2947490195178593. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.2051560502577123. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating mdoors adult all_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 4.162521638862333. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 4.064290812890514. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating mdoors adult all_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# Calculating social adult positive_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.8494247606211562. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.436136620143237. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating social adult positive_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 4.6372008311859805. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 4.307819048965544. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating social adult negative_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.760584719808725. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.4152985795313264. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating social adult negative_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# Calculating social adult posVneg_win contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.8616443246950762. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.9108167430938874. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating social adult posVneg_win contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# Calculating social adult all_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 4.11715965353415. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.6959793839420856. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating social adult all_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images

# %% [markdown]
# ### Monetary Task

# %% [markdown]
# #### Positive win > Positive loss

# %%
filename = data_dir+'/group/'+'adult_mdoors_positive_winVlos_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)

# %% [markdown]
# #### All wins > All losses

# %%
filename = data_dir+'/group/'+'adult_mdoors_all_winVlos_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)

# %% [markdown]
# #### Positive wins > Negative wins

# %%
filename = data_dir+'/group/'+'adult_mdoors_posVneg_win_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)

# %% [markdown]
# ### Social Task

# %% [markdown]
# #### Positive win > Positive loss

# %%
filename = data_dir+'/group/'+'adult_social_positive_winVlos_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)

# %% [markdown]
# #### All wins > All losses

# %%
filename = data_dir+'/group/'+'adult_social_all_winVlos_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)

# %% [markdown]
# ### Positive wins > Negative wins

# %%
filename = data_dir+'/group/'+'adult_social_posVneg_win_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)

# %% [markdown]
# # All Subjects

# %%
subjs_info_num = subjs_info.copy()
subjs_info_num = subjs_info_num.replace({'sex': {'F': 0, 'M': 1},
                                         'group': {'college': -1, 'kid': 1}})
subjs_info_num = subjs_info_num.drop(columns=['age', 'sex'])

design_matrix = make_second_level_design_matrix(subjs_list, subjs_info_num)

plot_design_matrix(design_matrix)
# Out:
# /var/folders/bj/bjn1471s0735c7771plnzsz00000gn/T/ipykernel_40617/4178790924.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   subjs_info_num = subjs_info_num.replace({'sex': {'F': 0, 'M': 1},
# <Axes: label='conditions', ylabel='scan number'>

# %%
contrasts = ['positive_winVlos', 'negative_winVlos', 'posVneg_win', 'all_winVlos']
contrasts_2nd = ['group','intercept']
tasks = ['mdoors','social']
group = 'all'
mc = 'fdr'
alpha = 0.05


for task in tasks:
    for contrast in contrasts:
            
        calc_second_level(group=group, subjs_list=subjs_list, task=task, 
                          contrast=contrast, contrasts_2nd=contrasts_2nd, space=None)
    
        calc_second_level(group=group, subjs_list=subjs_list, task=task, 
                          contrast=contrast, contrasts_2nd=contrasts_2nd, space='SUIT')
# Out:
# Calculating mdoors all positive_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.6747215256221732. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating mdoors all positive_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.6443298455072646. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.943605381327128. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating mdoors all negative_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.503031307770587. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating mdoors all negative_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.091028803895338. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.334470063253647. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating mdoors all posVneg_win contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.7052415470979367. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.8914484781730008. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating mdoors all posVneg_win contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 4.556086714350013. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.7010686906446866. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating mdoors all all_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.5613320723629025. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating mdoors all all_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.3485094957123254. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 2.8710039698459244. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating social all positive_winVlos contrast
# Calculating social all positive_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.14853532127744. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# Calculating social all negative_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.2884682251007575. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating social all negative_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 2.8327465704324206. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.748231238056955. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating social all posVneg_win contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.5363432766398195. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating social all posVneg_win contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.2817344926723138. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.9384439795228445. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating social all all_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 4.240765308822907. But, you have given threshold=inf.
#   stat_img = threshold_img(
# Calculating social all all_winVlos contrast
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/glm/thresholding.py:303: UserWarning: The given float value must not exceed 3.3722401193752956. But, you have given threshold=inf.
#   stat_img = threshold_img(
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/maskers/nifti_masker.py:114: UserWarning: imgs are being resampled to the mask_img resolution. This process is memory intensive. You might want to provide a target_affine that is equal to the affine of the imgs or resample the mask beforehand to save memory and computation time.
#   warnings.warn(
# [SecondLevelModel.compute_contrast] Resampling images

# %% [markdown]
# ## Group differences
# Where adolescents > young adults

# %% [markdown]
# ### Monetary Task

# %% [markdown]
# #### Positive win > Positive loss

# %%
filename = data_dir+'/group/'+'all_mdoors_positive_winVlos_group'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)

# %% [markdown]
# #### All wins > All losses

# %%
filename = data_dir+'/group/'+'all_mdoors_all_winVlos_group'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)

# %% [markdown]
# ### Positive win > Negative win

# %%
filename = data_dir+'/group/'+'all_mdoors_posVneg_win_group'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)

# %% [markdown]
# ### Social Task

# %% [markdown]
# #### Positive win > Positive loss

# %%
filename = data_dir+'/group/'+'all_social_positive_winVlos_group'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)

# %% [markdown]
# #### All wins > All losses

# %%
filename = data_dir+'/group/'+'all_social_all_winVlos_group'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)

# %% [markdown]
# ### Positive win > Negative win

# %%
filename = data_dir+'/group/'+'all_social_posVneg_win_group'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)

# %% [markdown]
# ## Accounting for Group

# %% [markdown]
# ### Monetary Task

# %% [markdown]
# #### Positive win > Positive loss

# %%
filename = data_dir+'/group/'+'all_mdoors_positive_winVlos_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)

# %% [markdown]
# #### All wins > All losses

# %%
filename = data_dir+'/group/'+'all_mdoors_all_winVlos_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)

# %% [markdown]
# ### Positive win > Negative win

# %%
filename = data_dir+'/group/'+'all_mdoors_posVneg_win_group'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)

# %% [markdown]
# ### Social Task

# %% [markdown]
# #### Positive wins > Positive losses

# %%
filename = data_dir+'/group/'+'all_social_positive_winVlos_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)

# %% [markdown]
# #### All wins > All losses

# %%
filename = data_dir+'/group/'+'all_social_all_winVlos_intercept'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)

# %% [markdown]
# ### Positive win > Negative win

# %%
filename = data_dir+'/group/'+'all_social_posVneg_win_group'

helpful_functions.plot_transparent_threshold(filename, thresh=.05)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)
# /opt/anaconda3/lib/python3.11/site-packages/nilearn/plotting/displays/_slicers.py:366: UserWarning: empty mask
#   self._map_show(img, type="contour", threshold=threshold, **kwargs)

# %% [markdown]
# # Behavioral Analysis
#
# Not updated

# %%
behav_data = pd.read_excel(bids_dir+'/derivatives/behavioral/aggregate_full_data_SPSS_020419.xlsx',
                          sheet_name='Sheet1')

behav_data.head()
# Out:
#    Order Subject  ch_totanx  ch_socialanx  p_totanx  p_socialanx  bfne  \
# 0      1    s010         51            14         7            1    33
# 1      1    s011         12             3         4            1    31
# 2      1    s013          8             4         1            1    13
# 3      1    s015         18             5         1            0    21
# 4      2    s024         21            10         0            0    28
#
#    ch_cdi_total  ch_cdi_interpersonal  ch_cdi_anhedonia  ...  \
# 0          11.0                   0.0               5.0  ...
# 1           8.0                   0.0               3.0  ...
# 2           5.0                   0.0               2.0  ...
# 3           NaN                   NaN               NaN  ...
# 4           1.0                   0.0               0.0  ...
#
#    FB_VS_6mm_R_Like_Lose_NZMean_1  FB_VS_6mm_R_Like_Lose_NZCount_1  \
# 0                        0.029036                            123.0
# 1                             NaN                              NaN
# 2                       -0.308424                            123.0
# 3                       -0.798996                            123.0
# 4                             NaN                              NaN
#
#    FB_VS_6mm_R_Like_Lose_NZMin_1  FB_VS_6mm_R_Like_Lose_NZMax_1  \
# 0                      -0.296210                       0.647286
# 1                            NaN                            NaN
# 2                      -0.554069                       0.030482
# 3                      -1.841710                      -0.031699
# 4                            NaN                            NaN
#
#   FB_VS_6mm_R_Like_Win_Mean_1  FB_VS_6mm_R_Like_Win_NZMean_1  \
# 0                    0.256033                       0.256033
# 1                         NaN                            NaN
# 2                    0.093248                       0.093248
# 3                    0.004660                       0.004660
# 4                         NaN                            NaN
#
#    FB_VS_6mm_R_Like_Win_NZCount_1  FB_VS_6mm_R_Like_Win_NZMin_1  \
# 0                           123.0                     -0.022722
# 1                             NaN                           NaN
# 2                           123.0                     -0.183241
# 3                           123.0                     -1.020790
# 4                             NaN                           NaN
#
#    FB_VS_6mm_R_Like_Win_NZMax_1  FB_VS6mm_L_Correct_DislikeVsLike
# 0                      0.752379                         -0.127002
# 1                           NaN                               NaN
# 2                      1.003483                         -0.167305
# 3                      0.809193                          0.485397
# 4                           NaN                               NaN
#
# [5 rows x 1551 columns]

# %%
behav_data_fltr = behav_data[['Subject','ch_totanx', 'ch_cdi_total']]

behav_data_fltr['Subject'] = behav_data_fltr['Subject'].str.replace('s','sub-')

behav_data_fltr = behav_data_fltr.rename(columns={'Subject':'subject_label'})

behav_data_fltr.head()
# Out:
# /Users/haroonpopal/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#   subject_label  ch_totanx  ch_cdi_total
# 0       sub-010         51          11.0
# 1       sub-011         12           8.0
# 2       sub-013          8           5.0
# 3       sub-015         18           NaN
# 4       sub-024         21           1.0

# %%
# Add behavioral data to design matrix

subjs_info_kids_behav = subjs_info_kids_fltr.merge(behav_data_fltr, on='subject_label')


design_matrix = make_second_level_design_matrix(subjs_list_kids, subjs_info_kids_behav)

plot_design_matrix(design_matrix)
# Out:
# /Users/haroonpopal/anaconda3/envs/py37/lib/python3.7/site-packages/nilearn/glm/first_level/design_matrix.py:475: UserWarning: Attention: Design matrix is singular. Aberrant estimates are expected.
#   warn('Attention: Design matrix is singular. Aberrant estimates '
# <AxesSubplot:label='conditions', ylabel='scan number'>

# %%
#design_matrix = make_second_level_design_matrix(subjs_list_kids, subjs_info_kids_fltr)
mni_mask = bids_dir+"/derivatives/fmriprep/sub-010/anat/sub-010_space-MNI152NLin2009cAsym_label-GM_probseg_bin.nii.gz"

#contrasts = ['valence_x_outcome',
#             'positive','positive_win','positive_loss',
#             'negative','negative_win','negative_loss']
contrasts=['all_winVlos', 'positive_winVlos']
contrasts_2nd = ['ch_totanx','ch_cdi_total']
tasks = ['mdoors','social']
group = 'kids'
alpha = 0.001


threshold_data = {}

for task in tasks:
    for contrast in contrasts:
        
        temp_file_list = []
        for subj in subjs_list_kids:
            temp_file = glob.glob(os.path.join(data_dir,subj,'zmap_'+task+'_'+contrast+'.nii'))
            temp_file_list.append(temp_file[0])
        temp_file_list.sort()
        
        print('Calculating '+task+' group '+contrast+' contrast')
        
        model = SecondLevelModel(mask_img=mni_mask, smoothing_fwhm=8.0)
        model.fit(temp_file_list, design_matrix=design_matrix)
        
        for contrast_2nd in contrasts_2nd:
            z_map = model.compute_contrast(contrast_2nd, output_type='z_score')

            z_map.to_filename(os.path.join(data_dir,'group',
                                       'zmap_'+group+'_'+task+'_'+contrast+'_'+contrast_2nd+'_unc.nii.gz'))
            
            # Multiple Comparisons Correction
            z_map_thresh, threshold = threshold_stats_img(z_map, alpha=alpha, height_control='fpr')
            z_map_thresh.to_filename(os.path.join(data_dir,'group',
                                       'zmap_'+group+'_'+task+'_'+contrast+'_'+contrast_2nd+'_fpr.nii.gz'))
            
            threshold_data['zmap_'+group+'_'+task+'_'+contrast+'_'+contrast_2nd+'_fpr_'+str(alpha)] = threshold
# Out:
# Calculating mdoors group all_winVlos contrast
# Calculating mdoors group positive_winVlos contrast
# Calculating social group all_winVlos contrast
# Calculating social group positive_winVlos contrast

# %%
filename = 'zmap_kids_social_positive_winVlos_ch_cdi_total_'
threshold = threshold_data[filename+'fpr_'+str(alpha)]
#threshold=1

plot_stat_map_cb(filename+'unc', threshold)

# %%
filename = 'zmap_kids_social_all_winVlos_ch_cdi_total_'
threshold = threshold_data[filename+'fpr_'+str(alpha)]
#threshold=1

plot_stat_map_cb(filename+'unc', threshold)
